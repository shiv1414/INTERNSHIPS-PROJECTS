# %%
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup

from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

import requests

import re
from selenium.webdriver.common.by import By

import warnings
warnings.filterwarnings('ignore')

# %%
driver = webdriver.Chrome('chromedriver.exe')

# %%
url = "https://www.cars24.com/buy-used-car?sort=P&storeCityId=2&pinId=110001"
driver.get(url)

# %%
# fetching the product url

urls = []
start = 0
end = 3
for page in range(start,end):
    tit = driver.find_elements(By.XPATH,'//div[@class="col-4"]/a')
    for i in tit:
        urls.append(i.get_attribute('href'))
        
    next_bu = driver.find_elements(By.XPATH,"/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[65]/div/div/span/a[3]")

# %%
len(urls)
# Out:
# 2007

# %%
urls
# Out:
# ['https://www.cars24.com/buy-used-hyundai-verna-2019-cars-gurgaon-1018594465/',
#  'https://www.cars24.com/buy-used-kia-seltos-2020-cars-new-delhi-1005526164/',
#  'https://www.cars24.com/buy-used-maruti-swift-2020-cars-noida-10547199747/',
#  'https://www.cars24.com/buy-used-maruti-swift-2019-cars-new-delhi-10060599733/',
#  'https://www.cars24.com/buy-used-kia-seltos-2020-cars-gurgaon-10158795723/',
#  'https://www.cars24.com/buy-used-mercedes-benz-c-class-2014-cars-new-delhi-1050064264/',
#  'https://www.cars24.com/buy-used-maruti-swift-2020-cars-new-delhi-10002493744/',
#  'https://www.cars24.com/buy-used-hyundai-i10-2013-cars-gurgaon-10141691737/',
#  'https://www.cars24.com/buy-used-renault-kiger-2021-cars-noida-10576492729/',
#  'https://www.cars24.com/buy-used-mg-astor-2022-cars-new-delhi-10170398732/',
#  'https://www.cars24.com/buy-used-honda-city-2014-cars-gurgaon-10184794731/',
#  'https://www.cars24.com/buy-used-jaguar-xf-2013-cars-ghaziabad-1128366066/',
# ...

# %%
# fetching the name of the product

names = []

for i in urls:
    driver.get(i)
    time.sleep(3)
    try:
        pro = driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div/div/div/div[1]/div[2]/h2')
        names.append(pro.text)
        
    except NoSuchElementException :
        names.append('Not Present')

# %%
len(names)
# Out:
# 2007

# %%
names
# Out:
# ['2019 Hyundai Verna 1.6 SX VTVT (O) MANUAL',
#  '2020 KIA SELTOS GTX + AT PETROL AUTOMATIC',
#  '2020 Maruti Swift LXI MANUAL',
#  '2019 Maruti Swift LXI MANUAL',
#  '2020 KIA SELTOS HTX 1.5 PETROL MT MANUAL',
#  '2014 Mercedes Benz C Class C 200 AVANTGARDE AUTOMATIC',
#  '2020 Maruti Swift LXI MANUAL',
#  '2013 Hyundai i10 ERA 1.1 IRDE MANUAL',
#  '2021 Renault Kiger RXZ 1.0 MT DUAL TONE',
#  '2022 MG ASTOR SHARP (O) 1.5 CVT IVORY AUTOMATIC',
#  '2014 Honda City VX MT PETROL MANUAL',
#  '2013 Jaguar XF 2.2 DIESEL AUTOMATIC',
#  '2021 Renault Kwid 1.0 RXT Opt MANUAL',
#  '2020 Hyundai NEW SANTRO 1.1 ERA EXICUTIVE MANUAL',
#  '2021 Tata ALTROZ XM+ 1.2 RTN',
#  '2021 Maruti Swift LXI MANUAL',
#  '2019 KIA SELTOS HTK PLUS 1.5 DIESEL MANUAL',
#  '2019 Maruti Swift LXI MANUAL',
#  '2018 Maruti Dzire LXI MANUAL',
#  '2017 Honda WR-V 1.2 i-VTEC VX MT MANUAL',
#  '2019 KIA SELTOS GTX + AT PETROL AUTOMATIC',
#  '2021 Tata ALTROZ XE 1.2 MANUAL',
#  '2020 MG HECTOR PLUS SHARP DCT',
# ...

# %%
model = []

for i in names:
    model.append(i[0:4])
    
model
# Out:
# ['2019',
#  '2020',
#  '2020',
#  '2019',
#  '2020',
#  '2014',
#  '2020',
#  '2013',
#  '2021',
#  '2022',
#  '2014',
#  '2013',
#  '2021',
#  '2020',
#  '2021',
#  '2021',
#  '2019',
#  '2019',
#  '2018',
#  '2017',
#  '2019',
#  '2021',
#  '2020',
#  '2022',
#  '2021',
#  '2011',
#  '2022',
#  '2014',
#  '2014',
#  '2010',
#  '2009',
#  '2020',
#  '2019',
#  '2020',
#  '2020',
#  '2020',
#  '2021',
#  '2021',
#  '2014',
#  '2019',
#  '2019',
#  '2020',
#  '2014',
#  '2021',
#  '2018',
#  '2013',
#  '2015',
#  '2017',
#  '2012',
#  '2016',
#  '2021',
#  '2020',
#  '2021',
#  '2017',
#  '2020',
#  '2013',
#  '2015',
#  '2014',
#  '2019',
#  '2020',
#  '2020',
#  '2020',
#  '2021',
#  '2015',
#  '2019',
#  '2013',
#  '2018',
#  '2014',
#  '2021',
#  '2021',
#  '2020',
#  '2016',
#  '2015',
#  '2019',
#  '2011',
#  '2019',
#  '2021',
#  '2021',
#  '2013',
#  '2016',
#  '2018',
#  '2013',
#  '2021',
#  '2019',
#  '2019',
#  '2020',
#  '2020',
#  '2021',
#  '2021',
#  '2013',
# ...

# %%
Car = []
for i in names:
    Car.append(i[4:30])
    
Car
# Out:
# [' Hyundai Verna 1.6 SX VTVT',
#  ' KIA SELTOS GTX + AT PETRO',
#  ' Maruti Swift LXI MANUAL',
#  ' Maruti Swift LXI MANUAL',
#  ' KIA SELTOS HTX 1.5 PETROL',
#  ' Mercedes Benz C Class C 2',
#  ' Maruti Swift LXI MANUAL',
#  ' Hyundai i10 ERA 1.1 IRDE ',
#  ' Renault Kiger RXZ 1.0 MT ',
#  ' MG ASTOR SHARP (O) 1.5 CV',
#  ' Honda City VX MT PETROL M',
#  ' Jaguar XF 2.2 DIESEL AUTO',
#  ' Renault Kwid 1.0 RXT Opt ',
#  ' Hyundai NEW SANTRO 1.1 ER',
#  ' Tata ALTROZ XM+ 1.2 RTN',
#  ' Maruti Swift LXI MANUAL',
#  ' KIA SELTOS HTK PLUS 1.5 D',
#  ' Maruti Swift LXI MANUAL',
#  ' Maruti Dzire LXI MANUAL',
#  ' Honda WR-V 1.2 i-VTEC VX ',
#  ' KIA SELTOS GTX + AT PETRO',
#  ' Tata ALTROZ XE 1.2 MANUAL',
#  ' MG HECTOR PLUS SHARP DCT',
#  ' Nissan MAGNITE XL Turbo M',
#  ' Renault Kiger RXT 1.0 AMT',
#  ' Hyundai i10 MAGNA 1.2 KAP',
#  ' Tata ALTROZ XZ 1.2 MANUAL',
#  ' Hyundai i10 MAGNA 1.1 IRD',
#  ' Maruti Alto 800 VXI MANUA',
#  ' Maruti Alto LXI MANUAL',
# ...

# %%
len(Car)
# Out:
# 2007

# %%
len(model)
# Out:
# 2007

# %%
# fetching the Price of the product

Price = []

for i in urls:
    driver.get(i)
    time.sleep(1)
    try:
        pros = driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div/div/div/div[1]/div[3]/strong')
        Price.append(pros.text[12:])
        
    except NoSuchElementException :
        Price.append('Not Present')

# %%
len(Price)
# Out:
# 2007

# %%
Price
# Out:
# ['₹9,81,699',
#  '₹18,95,199',
#  '₹5,92,499',
#  '₹5,33,399',
#  '₹13,83,099',
#  '₹20,33,499',
#  '₹5,66,799',
#  '₹2,71,699',
#  '₹8,23,199',
#  '₹17,67,999',
#  '₹6,58,499',
#  '₹15,49,999',
#  '₹5,05,099',
#  '₹4,71,599',
#  ',20,176',
#  '₹6,11,299',
#  '₹13,07,499',
#  ',56,999',
#  '₹5,42,299',
#  ',79,899',
#  '₹16,59,099',
#  '₹6,41,999',
#  '₹18,90,299',
#  '₹8,43,099',
#  '₹8,30,299',
#  '₹2,82,899',
#  '₹8,61,699',
#  '₹3,49,399',
#  '₹2,70,299',
#  '₹1,70,299',
#  ',99,699',
#  '₹6,00,999',
#  '₹13,76,149',
#  '₹11,89,899',
#  '₹18,48,299',
#  '₹6,08,399',
#  '₹4,63,499',
#  '₹11,83,499',
#  '₹2,75,299',
#  '20,12,799',
#  '₹19,41,699',
#  '₹4,06,399',
#  '₹3,39,599',
#  '₹7,07,999',
#  '₹11,49,399',
#  '₹11,26,499',
#  '₹5,30,099',
#  '₹7,32,399',
#  '₹2,57,999',
#  '₹5,38,599',
#  '₹13,84,399',
#  '₹4,52,199',
#  '₹7,31,399',
#  '₹7,88,599',
#  '₹17,55,399',
#  '₹3,98,999',
#  '₹4,32,499',
#  '₹3,42,699',
#  '₹17,94,899',
#  '₹13,14,099',
#  '₹5,06,599',
# ...

# %%
# fetching the Driven kilometers of the product

driven = []

for i in urls:
    driver.get(i)
    time.sleep(2)
    try:
        pros = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[3]/strong')
        driven.append(pros.text)
        
    except NoSuchElementException :
        driven.append('Not Present')

# %%
len(driven)
# Out:
# 2007

# %%
driven
# Out:
# ['81,902 km',
#  '8,241 km',
#  '10,568 km',
#  '27,659 km',
#  '32,799 km',
#  '37,531 km',
#  '19,919 km',
#  '38,139 km',
#  '14,474 km',
#  '2,091 km',
#  '61,168 km',
#  '28,909 km',
#  '368 km',
#  '3,812 km',
#  '7,416 km',
#  '5,078 km',
#  '25,067 km',
#  '24,967 km',
#  '25,788 km',
#  '17,511 km',
#  '37,357 km',
#  '7,472 km',
#  '3,483 km',
#  '5,306 km',
#  '6,192 km',
#  '72,229 km',
#  '1,086 km',
#  '41,439 km',
#  '28,210 km',
#  '48,001 km',
#  '44,327 km',
#  '13,525 km',
#  '42,490 km',
#  '32,873 km',
#  '12,185 km',
#  '6,470 km',
#  '13,021 km',
#  '6,724 km',
#  '63,753 km',
#  '23,327 km',
#  '46,860 km',
#  '6,669 km',
#  '41,822 km',
#  '15,844 km',
#  '34,073 km',
#  '71,180 km',
#  '25,414 km',
#  '58,689 km',
#  '55,018 km',
#  '48,381 km',
#  '38,187 km',
#  '10,572 km',
#  '649 km',
#  '38,072 km',
#  '16,315 km',
#  '25,068 km',
#  '46,245 km',
#  '59,277 km',
#  '9,378 km',
#  '19,359 km',
#  '15,199 km',
#  '33,981 km',
#  '13,713 km',
# ...

# %%
# fetching the hsitory of the car

history = []

for i in urls:
    driver.get(i)
    time.sleep(1)
    try:
        pros = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[1]/strong')
        history.append(pros.text)
        
    except NoSuchElementException :
        history.append('Not Present')

# %%
len(history)
# Out:
# 2007

# %%
history
# Out:
# ['Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
# ...

# %%
# fetching the Last servive  of the car

ser = []

for i in urls:
    driver.get(i)
    time.sleep(2)
    try:
        pros = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[5]/strong')
        ser.append(pros.text[0:7])
        
    except NoSuchElementException :
        ser.append('Not Present')

# %%
len(ser)
# Out:
# 2007

# %%
ser
# Out:
# ['81,902k',
#  '8,241km',
#  '10,568k',
#  '27,659k',
#  '32,799k',
#  '37,531k',
#  '19,919k',
#  '38,139k',
#  '14,474k',
#  '2,091km',
#  '61,168k',
#  '28,909k',
#  '368km (',
#  '3,812km',
#  '7,416km',
#  '5,078km',
#  '25,067k',
#  '24,967k',
#  '25,788k',
#  '17,511k',
#  '37,357k',
#  '7,472km',
#  '3,483km',
#  '5,306km',
#  '6,192km',
#  '72,229k',
#  '1,086km',
#  '41,439k',
#  '28,210k',
#  '48,001k',
#  '44,327k',
#  '13,525k',
#  '42,490k',
#  '32,873k',
#  '12,185k',
#  '6,470km',
#  '13,021k',
#  '6,724km',
#  '63,753k',
#  '23,327k',
#  '46,860k',
#  '6,669km',
#  '41,822k',
#  '15,844k',
#  '34,073k',
#  '71,180k',
#  '25,414k',
#  '58,689k',
#  '55,018k',
#  '48,381k',
#  '38,187k',
#  '10,572k',
#  '649km (',
#  '38,072k',
#  '16,315k',
#  '25,068k',
#  '46,245k',
#  '59,277k',
#  '9,378km',
#  '19,359k',
#  '15,199k',
#  '33,981k',
#  '13,713k',
#  '36,483k',
#  '35,953k',
#  '60,368k',
#  '2,920km',
#  '83,263k',
#  '7,733km',
#  '2,863km',
#  '32,605k',
# ...

# %%
# fetching the owner  of the car

owner = []

for i in urls:
    driver.get(i)
    time.sleep(2)
    try:
        pros = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[2]/strong')
        owner.append(pros.text)
        
    except NoSuchElementException :
        owner.append('Not Present')

# %%
len(owner)
# Out:
# 2007

# %%
owner
# Out:
# ['1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '3rd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
# ...

# %%
# fetching the Fuel type of the car

fuel = []

for i in urls[0:885]:
    driver.get(i)
    time.sleep(2)
    try:
        pros = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[4]/strong')
        fuel.append(pros.text)
        
    except NoSuchElementException :
        fuel.append('Not Present')

# %%
len(fuel)
# Out:
# 885

# %%
fuel
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
# ...

# %%
# fetching the Fuel type of the car

fuels = []

for i in urls[885:]:
    driver.get(i)
    time.sleep(2)
    try:
        pros = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[4]/strong')
        fuels.append(pros.text)
        
    except NoSuchElementException :
        fuels.append('Not Present')

# %%
len(fuels)
# Out:
# 1122

# %%
fuels
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol + CNG',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol + CNG',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
# ...

# %%
fuel.extend(fuels)
print(fuel)
# Out:
# ['Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol
# ...

# %%
len(fuel)
# Out:
# 2007

# %%
fuel
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
# ...

# %%
# fetching the owner  of the car

loc = []

for i in urls:
    driver.get(i)
    time.sleep(2)
    try:
        pros = driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/ul/li[3]')
        loc.append(pros.text)
        
    except NoSuchElementException :
        loc.append('Not Present')

# %%
len(loc)
# Out:
# 2007

# %%
loc
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
url = "https://www.cars24.com/buy-used-cars-noida/"
driver.get(url)

# %%
# fetching the product url

urls = []
start = 0
end = 3
for page in range(start,end):
    tit = driver.find_elements(By.XPATH,'//div[@class="col-4"]/a')
    for i in tit:
        urls.append(i.get_attribute('href'))
        
    next_bu = driver.find_elements(By.XPATH,"/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[65]/div/div/span/a[3]")

# %%
len(urls)
# Out:
# 1977

# %%
# fetching the name of the product

namess = []

for i in urls:
    driver.get(i)
    time.sleep(3)
    try:
        pro = driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div/div/div/div[1]/div[2]/h2')
        namess.append(pro.text)
        
    except NoSuchElementException :
        namess.append('Not Present')

# %%
len(namess)
# Out:
# 1977

# %%
namess
# Out:
# ['2015 Hyundai Elite i20 SPORTZ 1.2 MANUAL',
#  '2018 Maruti Dzire VXI AMT AUTOMATIC',
#  '2020 Maruti Swift LXI MANUAL',
#  '2021 Renault Kiger RXZ 1.0 MT DUAL TONE',
#  '2021 Renault Kwid 1.0 RXT Opt MANUAL',
#  '2019 MG HECTOR SHARP DCT PETROL AUTOMATIC',
#  '2016 Honda Amaze 1.2 SX MT I VTEC MANUAL',
#  '2020 Maruti Baleno SIGMA 1.2 K12 MANUAL',
#  '2021 Hyundai VENUE S MT 1.2 KAPPA MANUAL',
#  '2014 Maruti Swift VXI MANUAL',
#  '2016 Hyundai Grand i10 SPORTZ 1.2 KAPPA VTVT MANUAL',
#  '2017 Hyundai Grand i10 SPORTZ (O) 1.2 AT VTVT AUTOMATIC',
#  '2018 Maruti Swift VXI AMT AUTOMATIC',
#  '2017 Toyota Corolla Altis J S MANUAL',
#  '2018 Honda Amaze 1.2 S (O) MT I VTEC MANUAL',
#  '2016 Maruti Baleno DELTA 1.2 K12 AT AUTOMATIC',
#  '2020 Hyundai Creta 1.5 SX (O) AT AUTOMATIC',
#  '2019 Hyundai Grand i10 SPORTZ 1.2 KAPPA VTVT MANUAL',
#  '2020 Maruti Celerio VXI AMT AUTOMATIC',
#  '2020 Hyundai GRAND I10 NIOS SPORTZ PETROL MANUAL',
#  '2016 Renault Kwid RXT MANUAL',
# ...

# %%
models = []

for i in namess:
    models.append(i[0:4])
    
models
# Out:
# ['2015',
#  '2018',
#  '2020',
#  '2021',
#  '2021',
#  '2019',
#  '2016',
#  '2020',
#  '2021',
#  '2014',
#  '2016',
#  '2017',
#  '2018',
#  '2017',
#  '2018',
#  '2016',
#  '2020',
#  '2019',
#  '2020',
#  '2020',
#  '2016',
#  '2016',
#  '2019',
#  '2019',
#  '2019',
#  '2014',
#  '2019',
#  '2019',
#  '2018',
#  '2018',
#  '2017',
#  '2014',
#  '2020',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2019',
#  '2020',
#  '2019',
#  '2016',
#  '2022',
#  '2021',
#  '2020',
#  '2017',
#  '2018',
#  '2021',
#  '2019',
#  '2018',
#  '2013',
#  '2021',
#  '2011',
#  '2015',
#  '2019',
#  '2020',
#  '2021',
#  '2021',
#  '2016',
#  '2020',
#  '2018',
#  '2011',
#  '2020',
#  '2020',
#  '2021',
#  '2014',
#  '2020',
#  '2016',
#  '2013',
#  '2022',
#  '2021',
#  '2019',
#  '2013',
#  '2011',
#  '2021',
#  '2021',
#  '2020',
#  '2020',
#  '2015',
#  '2019',
#  '2019',
#  '2020',
#  '2021',
#  '2019',
#  '2019',
#  '2018',
#  '2019',
#  '2015',
#  '2017',
#  '2019',
#  '2019',
# ...

# %%
len(models)
# Out:
# 1977

# %%
Cars = []
for i in namess:
    Cars.append(i[4:30])
    
Cars
# Out:
# [' Hyundai Elite i20 SPORTZ ',
#  ' Maruti Dzire VXI AMT AUTO',
#  ' Maruti Swift LXI MANUAL',
#  ' Renault Kiger RXZ 1.0 MT ',
#  ' Renault Kwid 1.0 RXT Opt ',
#  ' MG HECTOR SHARP DCT PETRO',
#  ' Honda Amaze 1.2 SX MT I V',
#  ' Maruti Baleno SIGMA 1.2 K',
#  ' Hyundai VENUE S MT 1.2 KA',
#  ' Maruti Swift VXI MANUAL',
#  ' Hyundai Grand i10 SPORTZ ',
#  ' Hyundai Grand i10 SPORTZ ',
#  ' Maruti Swift VXI AMT AUTO',
#  ' Toyota Corolla Altis J S ',
#  ' Honda Amaze 1.2 S (O) MT ',
#  ' Maruti Baleno DELTA 1.2 K',
#  ' Hyundai Creta 1.5 SX (O) ',
#  ' Hyundai Grand i10 SPORTZ ',
#  ' Maruti Celerio VXI AMT AU',
#  ' Hyundai GRAND I10 NIOS SP',
#  ' Renault Kwid RXT MANUAL',
#  ' Renault Kwid RXT MANUAL',
#  ' Tata NEXON XM 1.2 MANUAL',
#  ' Jeep Compass 1.4 SPORT PE',
#  ' Jeep Compass 1.4 LONGITUD',
#  ' Honda City VX MT PETROL M',
#  ' Maruti Swift LXI MANUAL',
#  ' Jeep Compass 2.0 LIMITED ',
#  ' Jeep Compass 2.0 LONGITUD',
#  ' Maruti Dzire VXI AMT AUTO',
# ...

# %%
len(Cars)
# Out:
# 1977

# %%
# fetching the Price of the product

Prices = []

for i in urlss:
    driver.get(i)
    time.sleep(1)
    try:
        pros = driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div/div/div/div[1]/div[3]/strong')
        Prices.append(pros.text[12:])
        
    except NoSuchElementException :
        Prices.append('Not Present')

# %%
len(Prices)
# Out:
# 1977

# %%
Prices
# Out:
# ['₹5,30,099',
#  '₹6,64,999',
#  '₹5,92,499',
#  '₹8,23,199',
#  '₹5,05,099',
#  '₹16,93,499',
#  '₹5,71,299',
#  '₹5,51,299',
#  '₹8,34,099',
#  '₹4,41,899',
#  '₹4,85,599',
#  '₹5,77,599',
#  '₹6,26,699',
#  '₹7,72,499',
#  '₹5,06,299',
#  '₹5,27,799',
#  '₹17,55,399',
#  '₹4,99,899',
#  '₹5,74,699',
#  '₹6,76,399',
#  '₹2,74,399',
#  '₹2,56,899',
#  '₹6,68,899',
#  '₹13,76,149',
#  '₹19,92,799',
#  '₹6,30,099',
#  '₹5,33,399',
#  '18,18,999',
#  '₹12,04,299',
#  '₹6,64,999',
#  ',79,899',
#  '₹20,33,499',
#  '₹5,92,499',
#  '₹6,11,299',
#  '₹8,23,199',
#  ',20,176',
#  '₹5,05,099',
#  '₹16,93,499',
#  '₹4,73,299',
#  '₹9,81,699',
#  '₹5,71,299',
#  '₹8,61,699',
#  '₹6,41,999',
#  '₹5,66,799',
#  '₹7,32,399',
#  '₹11,84,199',
#  '₹7,31,399',
#  '₹16,65,399',
#  '₹6,62,399',
#  ',33,449',
#  '₹4,40,899',
#  '₹2,38,699',
#  '₹2,24,299',
#  '₹7,74,699',
#  '₹5,51,299',
#  '₹7,86,899',
#  '₹8,30,299',
#  '₹5,26,999',
#  '₹11,89,899',
#  '₹7,47,899',
#  '₹2,59,399',
#  '₹12,97,699',
# ...

# %%
# fetching the Driven kilometers of the product

drivenss = []

for i in urlss[1929:]:
    driver.get(i)
    time.sleep(2)
    try:
        pros = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[3]/strong')
        drivenss.append(pros.text)
        
    except NoSuchElementException :
        drivenss.append('Not Present')

# %%
len(drivens)
# Out:
# 1929

# %%
drivens
# Out:
# ['25,414 km',
#  '12,545 km',
#  '10,568 km',
#  '14,474 km',
#  '368 km',
#  '9,378 km',
#  '16,198 km',
#  '36,041 km',
#  '15,263 km',
#  '51,321 km',
#  '19,575 km',
#  '16,636 km',
#  '34,110 km',
#  '1,28,020 km',
#  '58,093 km',
#  '26,314 km',
#  '16,315 km',
#  '37,953 km',
#  '10,515 km',
#  '16,489 km',
#  '21,273 km',
#  '30,894 km',
#  '28,061 km',
#  '42,490 km',
#  '23,327 km',
#  '61,168 km',
#  '27,659 km',
#  '46,860 km',
#  '72,575 km',
#  '12,545 km',
#  '17,511 km',
#  '37,531 km',
#  '10,568 km',
#  '5,078 km',
#  '14,474 km',
#  '7,416 km',
#  '368 km',
#  '9,378 km',
#  '3,812 km',
#  '81,902 km',
#  '16,198 km',
#  '1,086 km',
#  '7,472 km',
#  '19,919 km',
#  '58,689 km',
#  '55,714 km',
#  '649 km',
#  '12,283 km',
#  '52,220 km',
#  '43,384 km',
#  '13,021 km',
#  '47,021 km',
#  '95,793 km',
#  '13,291 km',
#  '36,041 km',
#  '1,599 km',
#  '6,192 km',
#  '48,225 km',
#  '32,873 km',
#  '96,914 km',
#  '61,943 km',
#  '7,632 km',
#  '6,669 km',
# ...

# %%
len(drivenss)
# Out:
# 48

# %%
drivenss
# Out:
# ['83,441 km',
#  '87,463 km',
#  '56,993 km',
#  '89,846 km',
#  '14,613 km',
#  '34,525 km',
#  '27,082 km',
#  '74,743 km',
#  '34,068 km',
#  '31,335 km',
#  '74,012 km',
#  '42,162 km',
#  '50,409 km',
#  '55,856 km',
#  '28,447 km',
#  '60,820 km',
#  '55,609 km',
#  '56,195 km',
#  '24,670 km',
#  '72,062 km',
#  '73,708 km',
#  '1,61,137 km',
#  '1,19,766 km',
#  '39,317 km',
#  '53,859 km',
#  '58,807 km',
#  '42,236 km',
#  '87,784 km',
#  '1,22,884 km',
#  '95,601 km',
#  '38,666 km',
#  '88,616 km',
#  '76,009 km',
#  '30,528 km',
#  '72,852 km',
#  '47,617 km',
#  '46,867 km',
#  '52,839 km',
#  '76,155 km',
#  '83,583 km',
#  '1,14,858 km',
#  '73,654 km',
#  '70,100 km',
#  '9,628 km',
#  '88,972 km',
#  '30,072 km',
#  '59,332 km',
#  '26,406 km']

# %%
drivens.extend(drivenss)
print(drivens)
# Out:
# ['25,414 km', '12,545 km', '10,568 km', '14,474 km', '368 km', '9,378 km', '16,198 km', '36,041 km', '15,263 km', '51,321 km', '19,575 km', '16,636 km', '34,110 km', '1,28,020 km', '58,093 km', '26,314 km', '16,315 km', '37,953 km', '10,515 km', '16,489 km', '21,273 km', '30,894 km', '28,061 km', '42,490 km', '23,327 km', '61,168 km', '27,659 km', '46,860 km', '72,575 km', '12,545 km', '17,511 km', '37,531 km', '10,568 km', '5,078 km', '14,474 km', '7,416 km', '368 km', '9,378 km', '3,812 km', '81,902 km', '16,198 km', '1,086 km', '7,472 km', '19,919 km', '58,689 km', '55,714 km', '649 km', '12,283 km', '52,220 km', '43,384 km', '13,021 km', '47,021 km', '95,793 km', '13,291 km', '36,041 km', '1,599 km', '6,192 km', '48,225 km', '32,873 km', '96,914 km', '61,943 km', '7,632 km', '6,669 km', '15,263 km', '51,321 km', '44,823 km', '19,575 km', '71,180 km', '3,031 km', '38,187 km', '24,967 km', '30,013 km', '38,042 km', '12,090 km', '20,621 km', '4,216 km', '8,241 km', '28,170 km', '41,
# ...

# %%
len(drivens)
# Out:
# 1977

# %%
drivens
# Out:
# ['25,414 km',
#  '12,545 km',
#  '10,568 km',
#  '14,474 km',
#  '368 km',
#  '9,378 km',
#  '16,198 km',
#  '36,041 km',
#  '15,263 km',
#  '51,321 km',
#  '19,575 km',
#  '16,636 km',
#  '34,110 km',
#  '1,28,020 km',
#  '58,093 km',
#  '26,314 km',
#  '16,315 km',
#  '37,953 km',
#  '10,515 km',
#  '16,489 km',
#  '21,273 km',
#  '30,894 km',
#  '28,061 km',
#  '42,490 km',
#  '23,327 km',
#  '61,168 km',
#  '27,659 km',
#  '46,860 km',
#  '72,575 km',
#  '12,545 km',
#  '17,511 km',
#  '37,531 km',
#  '10,568 km',
#  '5,078 km',
#  '14,474 km',
#  '7,416 km',
#  '368 km',
#  '9,378 km',
#  '3,812 km',
#  '81,902 km',
#  '16,198 km',
#  '1,086 km',
#  '7,472 km',
#  '19,919 km',
#  '58,689 km',
#  '55,714 km',
#  '649 km',
#  '12,283 km',
#  '52,220 km',
#  '43,384 km',
#  '13,021 km',
#  '47,021 km',
#  '95,793 km',
#  '13,291 km',
#  '36,041 km',
#  '1,599 km',
#  '6,192 km',
#  '48,225 km',
#  '32,873 km',
#  '96,914 km',
#  '61,943 km',
#  '7,632 km',
#  '6,669 km',
# ...

# %%
# fetching the hsitory of the car

historys = []

for i in urlss:
    driver.get(i)
    time.sleep(1)
    try:
        pros = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[1]/strong')
        historys.append(pros.text)
        
    except NoSuchElementException :
        historys.append('Not Present')

# %%
len(historys)
# Out:
# 1977

# %%
historys
# Out:
# ['Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
# ...

# %%
# fetching the Last servive  of the car

seri = []

for i in urlss:
    driver.get(i)
    time.sleep(2)
    try:
        pros = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[5]/strong')
        seri.append(pros.text[0:7])
        
    except NoSuchElementException :
        seri.append('Not Present')

# %%
len(seri)
# Out:
# 1977

# %%
seri
# Out:
# ['25,414k',
#  '12,545k',
#  '10,568k',
#  '14,474k',
#  '368km (',
#  '9,378km',
#  '16,198k',
#  '36,041k',
#  '15,263k',
#  '51,321k',
#  '19,575k',
#  '16,636k',
#  '34,110k',
#  '1,28,02',
#  '58,093k',
#  '26,314k',
#  '16,315k',
#  '37,953k',
#  '10,515k',
#  '16,489k',
#  '21,273k',
#  '30,894k',
#  '28,061k',
#  '42,490k',
#  '23,327k',
#  '61,168k',
#  '27,659k',
#  '46,860k',
#  '72,575k',
#  '12,545k',
#  '17,511k',
#  '37,531k',
#  '10,568k',
#  '5,078km',
#  '14,474k',
#  '7,416km',
#  '368km (',
#  '9,378km',
#  '3,812km',
#  '81,902k',
#  '16,198k',
#  '1,086km',
#  '7,472km',
#  '19,919k',
#  '58,689k',
#  '55,714k',
#  '649km (',
#  '12,283k',
#  '52,220k',
#  '43,384k',
#  '13,021k',
#  '47,021k',
#  '95,793k',
#  '13,291k',
#  '36,041k',
#  '1,599km',
#  '6,192km',
#  '48,225k',
#  '32,873k',
#  '96,914k',
#  '61,943k',
#  '7,632km',
#  '6,669km',
#  '15,263k',
#  '51,321k',
#  '44,823k',
#  '19,575k',
#  '71,180k',
#  '3,031km',
#  '38,187k',
#  '24,967k',
# ...

# %%
# fetching the owner  of the car

owners = []

for i in urlss:
    driver.get(i)
    time.sleep(2)
    try:
        pros = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[2]/strong')
        owners.append(pros.text)
        
    except NoSuchElementException :
        owners.append('Not Present')

# %%
len(owners)
# Out:
# 1977

# %%
owners
# Out:
# ['1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
# ...

# %%
# fetching the Fuel type of the car

fuels = []

for i in urls[0:1403]:
    driver.get(i)
    time.sleep(1)
    try:
        pros = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[4]/strong')
        fuels.append(pros.text)
        
    except NoSuchElementException :
        fuels.append('Not Present')

# %%
len(fuels)
# Out:
# 1403

# %%
fuels
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol + CNG',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
# ...

# %%
len(fuelss)
# Out:
# 574

# %%
fuelss
# Out:
# ['Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol + CNG',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol + CNG',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
# ...

# %%
fuels.extend(fuelss)
print(fuels)
# Out:
# ['Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol + CNG', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol + CNG', 'Petrol', 'Petr
# ...

# %%
len(fuels)
# Out:
# 1977

# %%
# fetching the owner  of the car

locs = []

for i in urls[0:900]:
    driver.get(i)
    time.sleep(2)
    try:
        pros = driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/ul/li[3]')
        locs.append(pros.text)
        
    except NoSuchElementException :
        locs.append('Not Present')

# %%
len(locs)
# Out:
# 900

# %%
locs
# Out:
# ['Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
# ...

# %%
# fetching the owner  of the car

locss = []

for i in urls[900:1500]:
    driver.get(i)
    time.sleep(2)
    try:
        pros = driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/ul/li[3]')
        locss.append(pros.text)
        
    except NoSuchElementException :
        locss.append('Not Present')

# %%
len(locss)
# Out:
# 600

# %%
locss
# Out:
# ['Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
#  'Noida',
# ...

# %%
locs.extend(locss)
print(locs)
# Out:
# ['Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida'
# ...

# %%
len(locs)
# Out:
# 1500

# %%
# fetching the owner  of the car

locsss = []

for i in urls[1500:]:
    driver.get(i)
    time.sleep(2)
    try:
        pros = driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/ul/li[3]')
        locsss.append(pros.text)
        
    except NoSuchElementException :
        locsss.append('Not Present')

# %%
len(locsss)
# Out:
# 477

# %%
locs.extend(locsss)
print(locs)
# Out:
# ['Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida', 'Noida'
# ...

# %%
len(locs)
# Out:
# 1977

# %% [markdown]
# # CAR

# %%
Car.extend(Cars)
print(Car)
# Out:
# [' Hyundai Verna 1.6 SX VTVT', ' KIA SELTOS GTX + AT PETRO', ' Maruti Swift LXI MANUAL', ' Maruti Swift LXI MANUAL', ' KIA SELTOS HTX 1.5 PETROL', ' Mercedes Benz C Class C 2', ' Maruti Swift LXI MANUAL', ' Hyundai i10 ERA 1.1 IRDE ', ' Renault Kiger RXZ 1.0 MT ', ' MG ASTOR SHARP (O) 1.5 CV', ' Honda City VX MT PETROL M', ' Jaguar XF 2.2 DIESEL AUTO', ' Renault Kwid 1.0 RXT Opt ', ' Hyundai NEW SANTRO 1.1 ER', ' Tata ALTROZ XM+ 1.2 RTN', ' Maruti Swift LXI MANUAL', ' KIA SELTOS HTK PLUS 1.5 D', ' Maruti Swift LXI MANUAL', ' Maruti Dzire LXI MANUAL', ' Honda WR-V 1.2 i-VTEC VX ', ' KIA SELTOS GTX + AT PETRO', ' Tata ALTROZ XE 1.2 MANUAL', ' MG HECTOR PLUS SHARP DCT', ' Nissan MAGNITE XL Turbo M', ' Renault Kiger RXT 1.0 AMT', ' Hyundai i10 MAGNA 1.2 KAP', ' Tata ALTROZ XZ 1.2 MANUAL', ' Hyundai i10 MAGNA 1.1 IRD', ' Maruti Alto 800 VXI MANUA', ' Maruti Alto LXI MANUAL', ' Hyundai i10 ERA 1.1 IRDE ', ' Maruti Baleno SIGMA 1.2 K', ' Jeep Compass 1.4 SPORT PE', ' KIA SELTOS HTK 1.5 PETR
# ...

# %%
len(Car)
# Out:
# 3984

# %% [markdown]
# # MODEL

# %%
Model = []
for i in model[0:3984]:
    Model.append(i)
    
Model
# Out:
# ['2019',
#  '2020',
#  '2020',
#  '2019',
#  '2020',
#  '2014',
#  '2020',
#  '2013',
#  '2021',
#  '2022',
#  '2014',
#  '2013',
#  '2021',
#  '2020',
#  '2021',
#  '2021',
#  '2019',
#  '2019',
#  '2018',
#  '2017',
#  '2019',
#  '2021',
#  '2020',
#  '2022',
#  '2021',
#  '2011',
#  '2022',
#  '2014',
#  '2014',
#  '2010',
#  '2009',
#  '2020',
#  '2019',
#  '2020',
#  '2020',
#  '2020',
#  '2021',
#  '2021',
#  '2014',
#  '2019',
#  '2019',
#  '2020',
#  '2014',
#  '2021',
#  '2018',
#  '2013',
#  '2015',
#  '2017',
#  '2012',
#  '2016',
#  '2021',
#  '2020',
#  '2021',
#  '2017',
#  '2020',
#  '2013',
#  '2015',
#  '2014',
#  '2019',
#  '2020',
#  '2020',
#  '2020',
#  '2021',
#  '2015',
#  '2019',
#  '2013',
#  '2018',
#  '2014',
#  '2021',
#  '2021',
#  '2020',
#  '2016',
#  '2015',
#  '2019',
#  '2011',
#  '2019',
#  '2021',
#  '2021',
#  '2013',
#  '2016',
#  '2018',
#  '2013',
#  '2021',
#  '2019',
#  '2019',
#  '2020',
#  '2020',
#  '2021',
#  '2021',
#  '2013',
# ...

# %%
len(Model)
# Out:
# 3984

# %% [markdown]
# # PRICE

# %%
Price.extend(Prices)
print(Price)
# Out:
# ['₹9,81,699', '₹18,95,199', '₹5,92,499', '₹5,33,399', '₹13,83,099', '₹20,33,499', '₹5,66,799', '₹2,71,699', '₹8,23,199', '₹17,67,999', '₹6,58,499', '₹15,49,999', '₹5,05,099', '₹4,71,599', ',20,176', '₹6,11,299', '₹13,07,499', ',56,999', '₹5,42,299', ',79,899', '₹16,59,099', '₹6,41,999', '₹18,90,299', '₹8,43,099', '₹8,30,299', '₹2,82,899', '₹8,61,699', '₹3,49,399', '₹2,70,299', '₹1,70,299', ',99,699', '₹6,00,999', '₹13,76,149', '₹11,89,899', '₹18,48,299', '₹6,08,399', '₹4,63,499', '₹11,83,499', '₹2,75,299', '20,12,799', '₹19,41,699', '₹4,06,399', '₹3,39,599', '₹7,07,999', '₹11,49,399', '₹11,26,499', '₹5,30,099', '₹7,32,399', '₹2,57,999', '₹5,38,599', '₹13,84,399', '₹4,52,199', '₹7,31,399', '₹7,88,599', '₹17,55,399', '₹3,98,999', '₹4,32,499', '₹3,42,699', '₹17,94,899', '₹13,14,099', '₹5,06,599', '₹14,65,299', '₹8,41,249', '₹6,08,199', '₹6,03,299', '₹5,23,299', '₹4,08,999', '₹5,49,799', '₹9,01,699', '₹4,73,299', '₹15,39,699', '₹4,94,199', '₹5,43,799', '₹5,40,599', '₹2,59,399', '₹7,88,69
# ...

# %%
len(Price)
# Out:
# 3984

# %% [markdown]
# # DRIVEN KILOMETERS

# %%
driven.extend(drivens)
print(driven)
# Out:
# ['81,902 km', '8,241 km', '10,568 km', '27,659 km', '32,799 km', '37,531 km', '19,919 km', '38,139 km', '14,474 km', '2,091 km', '61,168 km', '28,909 km', '368 km', '3,812 km', '7,416 km', '5,078 km', '25,067 km', '24,967 km', '25,788 km', '17,511 km', '37,357 km', '7,472 km', '3,483 km', '5,306 km', '6,192 km', '72,229 km', '1,086 km', '41,439 km', '28,210 km', '48,001 km', '44,327 km', '13,525 km', '42,490 km', '32,873 km', '12,185 km', '6,470 km', '13,021 km', '6,724 km', '63,753 km', '23,327 km', '46,860 km', '6,669 km', '41,822 km', '15,844 km', '34,073 km', '71,180 km', '25,414 km', '58,689 km', '55,018 km', '48,381 km', '38,187 km', '10,572 km', '649 km', '38,072 km', '16,315 km', '25,068 km', '46,245 km', '59,277 km', '9,378 km', '19,359 km', '15,199 km', '33,981 km', '13,713 km', '36,483 km', '35,953 km', '60,368 km', '2,920 km', '83,263 km', '7,733 km', '2,863 km', '32,605 km', '20,452 km', '28,170 km', '21,043 km', '61,943 km', '13,291 km', '9,278 km', '9,236 km', '30,354 
# ...

# %%
len(driven)
# Out:
# 3984

# %% [markdown]
# # HISTORY

# %%
history.extend(historys)
print(history)
# Out:
# ['Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Ac
# ...

# %%
len(history)
# Out:
# 3984

# %% [markdown]
# # LAST SERVICE

# %%
ser.extend(seri)
print(ser)
# Out:
# ['81,902k', '8,241km', '10,568k', '27,659k', '32,799k', '37,531k', '19,919k', '38,139k', '14,474k', '2,091km', '61,168k', '28,909k', '368km (', '3,812km', '7,416km', '5,078km', '25,067k', '24,967k', '25,788k', '17,511k', '37,357k', '7,472km', '3,483km', '5,306km', '6,192km', '72,229k', '1,086km', '41,439k', '28,210k', '48,001k', '44,327k', '13,525k', '42,490k', '32,873k', '12,185k', '6,470km', '13,021k', '6,724km', '63,753k', '23,327k', '46,860k', '6,669km', '41,822k', '15,844k', '34,073k', '71,180k', '25,414k', '58,689k', '55,018k', '48,381k', '38,187k', '10,572k', '649km (', '38,072k', '16,315k', '25,068k', '46,245k', '59,277k', '9,378km', '19,359k', '15,199k', '33,981k', '13,713k', '36,483k', '35,953k', '60,368k', '2,920km', '83,263k', '7,733km', '2,863km', '32,605k', '20,452k', '28,170k', '21,043k', '61,943k', '13,291k', '9,278km', '9,236km', '30,354k', '48,225k', '96,751k', '59,194k', '15,795k', '45,067k', '12,452k', '7,632km', '12,418k', '35,187k', '14,458k', '65,005k', '55,163
# ...

# %%
len(ser)
# Out:
# 3984

# %% [markdown]
# # OWNER

# %%
owner.extend(owners)

# %%
print(owner)
# Out:
# ['1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '2nd Owner', '1st Owner', '2nd Owner', '2nd Owner', '1st Owner', '2nd Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '2nd Owner', '1st Owner', '2nd Owner', '1st Owner', '1st Owner', '2nd Owner', '1st Owner', '2nd Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '2nd Owner', '3rd Owner', '1st Owner', '1st Owner', '2nd Owner', '1st Owner', '1st Owner', '1st Owner', '2nd Owner', '1st Owner', '2nd Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '2nd Owner', '1st Owner', '1st Owner', '1st Owner', '2nd Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '2nd Owner', '2nd Owner', '1st Owner', '1st Owner', '1st Owner', '2nd Owner', '1st Owne
# ...

# %%
len(owner)
# Out:
# 3984

# %% [markdown]
# # FUEL TYPE

# %%
fuel.extend(fuels)
print(fuel)
# Out:
# ['Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol
# ...

# %%
len(fuel)
# Out:
# 3984

# %% [markdown]
# # LOCATION

# %%
loc.extend(locs)
print(loc)
# Out:
# ['New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delh
# ...

# %%
len(loc)
# Out:
# 3984

# %%
url = "https://www.cars24.com/buy-used-cars-ghaziabad/"
driver.get(url)

# %%
# fetching the product url

urlss = []
start = 0
end = 3
for page in range(start,end):
    tit = driver.find_elements(By.XPATH,'//div[@class="col-4"]/a')
    for i in tit:
        urlss.append(i.get_attribute('href'))
        
    next_bu = driver.find_elements(By.XPATH,"/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[65]/div/div/span/a[3]")

# %%
len(urlss)
# Out:
# 1926

# %%
# fetching the name of the product

nam = []

for i in urlss[0:1100]:
    driver.get(i)
    time.sleep(2)
    try:
        pro = driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div/div/div/div[1]/div[2]/h2')
        nam.append(pro.text)
        
    except NoSuchElementException :
        nam.append('Not Present')

# %%
modelsss = []

for i in nam:
    modelsss.append(i[0:4])
    
modelsss
# Out:
# ['2021',
#  '2021',
#  '2020',
#  '2015',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2015',
#  '2016',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2016',
#  '2017',
#  '2016',
#  '2021',
#  '2017',
#  '2015',
#  '2018',
#  '2021',
#  '2011',
#  '2020',
#  '2020',
#  '2019',
#  '2022',
#  '2020',
#  '2020',
#  '2021',
#  '2015',
#  '2021',
#  '2019',
#  '2021',
#  '2009',
#  '2021',
#  '2020',
#  '2018',
#  '2020',
#  '2020',
#  '2021',
#  '2019',
#  '2020',
#  '2020',
#  '2015',
#  '2018',
#  '2018',
#  '2021',
#  '2011',
#  '2018',
#  '2022',
#  '2021',
#  '2019',
#  '2019',
#  '2020',
#  '2011',
#  '2014',
#  '2016',
#  '2020',
#  '2019',
#  '2021',
#  '2020',
#  '2021',
#  '2018',
#  '2016',
#  '2017',
#  '2018',
#  '2021',
#  '2020',
#  '2020',
#  '2016',
#  '2019',
#  '2020',
#  '2022',
#  '2018',
#  '2020',
#  '2020',
#  '2021',
#  '2017',
#  '2019',
#  '2022',
#  '2021',
#  '2020',
#  '2011',
#  '2015',
#  '2020',
#  '2011',
#  '2017',
#  '2019',
#  '2020',
# ...

# %%
len(modelsss)
# Out:
# 1100

# %%
Ca = []
for i in nam:
    Ca.append(i[4:30])
    
Ca
# Out:
# [' Maruti Celerio ZXI AMT AU',
#  ' Renault Kwid 1.0 RXT Opt ',
#  ' Renault Kwid 1.0 RXT Opt ',
#  ' Maruti Celerio LXI MANUAL',
#  ' Maruti Swift VXI AMT AUTO',
#  ' Hyundai Elite i20 1.2 SPO',
#  ' Renault TRIBER 1.0 RXL PE',
#  ' Honda Amaze 1.2 V CVT I V',
#  ' Maruti Ciaz VXI PLUS MANU',
#  ' Hyundai Elite i20 MAGNA 1',
#  ' Honda City V MT PETROL MA',
#  ' Maruti Baleno DELTA 1.2 K',
#  ' Maruti Vitara Brezza VXI ',
#  ' Tata TIGOR XZ PLUS 1.2 RE',
#  ' Hyundai Elite i20 ASTA 1.',
#  ' Ford Ecosport 1.5 TITANIU',
#  ' Maruti Baleno DELTA 1.2 K',
#  ' Maruti IGNIS DELTA 1.2 K1',
#  ' Renault Duster RXZ AMT 11',
#  ' Hyundai i20 Active 1.2 S ',
#  ' Tata Tiago XE 1.2 REVOTRO',
#  ' Mahindra XUV 3OO 1.2 W6 M',
#  ' Hyundai i10 MAGNA 1.2 KAP',
#  ' Maruti New Wagon-R ZXI 1.',
#  ' Maruti New Wagon-R VXI 1.',
#  ' Maruti Swift VXI AMT AUTO',
#  ' MG ASTOR SHARP (O) 1.5 CV',
#  ' Maruti New Wagon-R ZXI 1.',
#  ' Honda City V MT PETROL MA',
#  ' Renault TRIBER 1.0 RXZ MA',
# ...

# %%
len(Ca)
# Out:
# 1100

# %%
len(nam)
# Out:
# 1100

# %%
nam
# Out:
# ['2021 Maruti Celerio ZXI AMT AUTOMATIC',
#  '2021 Renault Kwid 1.0 RXT Opt AT AUTOMATIC',
#  '2020 Renault Kwid 1.0 RXT Opt MANUAL',
#  '2015 Maruti Celerio LXI MANUAL',
#  '2019 Maruti Swift VXI AMT AUTOMATIC',
#  '2019 Hyundai Elite i20 1.2 SPORTS PLUS VTVT MANUAL',
#  '2019 Renault TRIBER 1.0 RXL PETROL MANUAL',
#  '2019 Honda Amaze 1.2 V CVT I VTEC AUTOMATIC',
#  '2015 Maruti Ciaz VXI PLUS MANUAL',
#  '2016 Hyundai Elite i20 MAGNA 1.2 MANUAL',
#  '2018 Honda City V MT PETROL MANUAL',
#  '2019 Maruti Baleno DELTA 1.2 K12 MANUAL',
#  '2020 Maruti Vitara Brezza VXI MANUAL',
#  '2021 Tata TIGOR XZ PLUS 1.2 REVOTRON MANUAL',
#  '2016 Hyundai Elite i20 ASTA 1.2 (O) MANUAL',
#  '2017 Ford Ecosport 1.5 TITANIUM TI VCT AT AUTOMATIC',
#  '2016 Maruti Baleno DELTA 1.2 K12 MANUAL',
#  '2021 Maruti IGNIS DELTA 1.2 K12 MANUAL',
#  '2017 Renault Duster RXZ AMT 110 PS AUTOMATIC',
#  '2015 Hyundai i20 Active 1.2 S MANUAL',
#  '2018 Tata Tiago XE 1.2 REVOTRON MANUAL',
# ...

# %%
# fetching the Price of the product

Pric = []

for i in urlss[0:1100]:
    driver.get(i)
    time.sleep(1)
    try:
        pros = driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div/div/div/div[1]/div[3]/strong')
        Pric.append(pros.text[12:])
        
    except NoSuchElementException :
        Pric.append('Not Present')

# %%
len(Pric)
# Out:
# 1100

# %%
Pric
# Out:
# ['₹6,07,599',
#  '₹5,00,799',
#  '₹4,06,399',
#  '₹3,53,899',
#  '₹6,57,599',
#  '₹6,82,799',
#  '₹5,56,099',
#  '₹7,63,799',
#  '₹5,25,299',
#  '₹5,07,699',
#  '₹8,15,699',
#  '₹6,35,499',
#  '₹7,92,799',
#  '₹8,11,599',
#  '₹6,07,899',
#  '₹7,17,099',
#  '₹5,39,899',
#  '₹6,42,999',
#  '₹7,04,499',
#  '₹5,41,299',
#  '₹4,25,099',
#  '₹9,65,699',
#  '₹2,38,699',
#  '₹6,08,599',
#  '₹5,54,899',
#  '₹6,22,999',
#  '₹17,67,999',
#  '₹6,08,599',
#  '₹10,14,199',
#  '₹7,86,899',
#  '₹4,34,999',
#  '₹5,00,799',
#  '₹6,68,899',
#  '₹9,13,499',
#  '₹2,02,099',
#  '₹6,84,099',
#  '₹5,74,699',
#  '₹4,49,499',
#  '₹4,06,399',
#  ',62,599',
#  '₹4,73,299',
#  '₹4,32,999',
#  '₹9,29,799',
#  '₹5,40,299',
#  '₹3,53,899',
#  '₹5,60,599',
#  '₹3,21,799',
#  '₹11,39,799',
#  '₹2,37,899',
#  '₹4,66,049',
#  '₹8,89,399',
#  '₹6,83,199',
#  '₹4,56,799',
#  '₹7,07,299',
#  '₹5,79,099',
#  '₹2,59,399',
#  '₹2,70,299',
#  '₹4,35,599',
#  '₹13,27,899',
#  ',45,299',
#  '₹8,23,199',
#  '₹5,94,899',
# ...

# %%
# fetching the Driven kilometers of the product

driv = []

for i in urlss[0:1100]:
    driver.get(i)
    time.sleep(2)
    try:
        pros = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[3]/strong')
        driv.append(pros.text)
        
    except NoSuchElementException :
        driv.append('Not Present')

# %%
len(driv)
# Out:
# 1100

# %%
driv
# Out:
# ['9,278 km',
#  '35,187 km',
#  '6,669 km',
#  '24,668 km',
#  '36,424 km',
#  '45,805 km',
#  '30,072 km',
#  '13,291 km',
#  '88,972 km',
#  '91,525 km',
#  '68,805 km',
#  '26,288 km',
#  '42,519 km',
#  '7,089 km',
#  '66,702 km',
#  '39,326 km',
#  '60,820 km',
#  '12,799 km',
#  '89,143 km',
#  '70,259 km',
#  '33,114 km',
#  '7,334 km',
#  '47,021 km',
#  '10,777 km',
#  '10,471 km',
#  '45,067 km',
#  '2,091 km',
#  '12,418 km',
#  '4,216 km',
#  '1,599 km',
#  '86,070 km',
#  '35,187 km',
#  '28,061 km',
#  '10,835 km',
#  '38,983 km',
#  '16,511 km',
#  '10,515 km',
#  '16,179 km',
#  '6,669 km',
#  '14,030 km',
#  '2,863 km',
#  '33,888 km',
#  '18,028 km',
#  '20,862 km',
#  '24,668 km',
#  '23,476 km',
#  '27,111 km',
#  '21,114 km',
#  '38,042 km',
#  '12,407 km',
#  '1,929 km',
#  '34,542 km',
#  '27,718 km',
#  '30,078 km',
#  '13,152 km',
#  '61,943 km',
#  '28,210 km',
#  '32,649 km',
#  '32,799 km',
#  '25,009 km',
#  '14,474 km',
#  '23,797 km',
#  '6,192 km',
# ...

# %%
# fetching the hsitory of the car

hist = []

for i in urlss[0:1100]:
    driver.get(i)
    time.sleep(1)
    try:
        pros = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[1]/strong')
        hist.append(pros.text)
        
    except NoSuchElementException :
        hist.append('Not Present')

# %%
len(hist)
# Out:
# 1100

# %%
hist
# Out:
# ['Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
#  'Non-Accidental',
# ...

# %%
# fetching the Last servive  of the car

serv = []

for i in urlss[0:1100]:
    driver.get(i)
    time.sleep(2)
    try:
        pros = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[5]/strong')
        serv.append(pros.text[0:7])
        
    except NoSuchElementException :
        serv.append('Not Present')

# %%
len(serv)
# Out:
# 1100

# %%
serv
# Out:
# ['9,278km',
#  '35,187k',
#  '6,669km',
#  '24,668k',
#  '36,424k',
#  '45,805k',
#  '30,072k',
#  '13,291k',
#  '88,972k',
#  '91,525k',
#  '68,805k',
#  '26,288k',
#  '42,519k',
#  '7,089km',
#  '66,702k',
#  '39,326k',
#  '60,820k',
#  '12,799k',
#  '89,143k',
#  '70,259k',
#  '33,114k',
#  '7,334km',
#  '47,021k',
#  '10,777k',
#  '10,471k',
#  '45,067k',
#  '2,091km',
#  '12,418k',
#  '4,216km',
#  '1,599km',
#  '86,070k',
#  '35,187k',
#  '28,061k',
#  '10,835k',
#  '38,983k',
#  '16,511k',
#  '10,515k',
#  '16,179k',
#  '6,669km',
#  '14,030k',
#  '2,863km',
#  '33,888k',
#  '18,028k',
#  '20,862k',
#  '24,668k',
#  '23,476k',
#  '27,111k',
#  '21,114k',
#  '38,042k',
#  '12,407k',
#  '1,929km',
#  '34,542k',
#  '27,718k',
#  '30,078k',
#  '13,152k',
#  '61,943k',
#  '28,210k',
#  '32,649k',
#  '32,799k',
#  '25,009k',
#  '14,474k',
#  '23,797k',
#  '6,192km',
#  '34,073k',
#  '9,009km',
#  '26,406k',
#  '12,545k',
#  '6,724km',
#  '3,812km',
#  '36,041k',
#  '19,577k',
# ...

# %%
# fetching the owner  of the car

own = []

for i in urlss[0:1100]:
    driver.get(i)
    time.sleep(1)
    try:
        pros = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[2]/strong')
        own.append(pros.text)
        
    except NoSuchElementException :
        own.append('Not Present')

# %%
len(own)
# Out:
# 1100

# %%
own
# Out:
# ['1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '1st Owner',
#  '2nd Owner',
#  '2nd Owner',
#  '1st Owner',
# ...

# %%
# fetching the Fuel type of the car

fue = []

for i in urlss[0:1100]:
    driver.get(i)
    time.sleep(2)
    try:
        pros = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/section[1]/div/div/div/div[1]/div/ul/li[4]/strong')
        fue.append(pros.text)
        
    except NoSuchElementException :
        fue.append('Not Present')

# %%
len(fue)
# Out:
# 1100

# %%
fue
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol + CNG',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol + CNG',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
# ...

# %%
# fetching the owner  of the car

loci = []

for i in urlss[0:1100]:
    driver.get(i)
    time.sleep(2)
    try:
        pros = driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/ul/li[3]')
        loci.append(pros.text)
        
    except NoSuchElementException :
        loci.append('Not Present')

# %%
len(loci)
# Out:
# 1100

# %%
loci
# Out:
# ['Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
# ...

# %% [markdown]
# # FINAL DATASET

# %% [markdown]
# # CARS NAME

# %%
Car.extend(Ca)
print(Car)
# Out:
# [' Hyundai Verna 1.6 SX VTVT', ' KIA SELTOS GTX + AT PETRO', ' Maruti Swift LXI MANUAL', ' Maruti Swift LXI MANUAL', ' KIA SELTOS HTX 1.5 PETROL', ' Mercedes Benz C Class C 2', ' Maruti Swift LXI MANUAL', ' Hyundai i10 ERA 1.1 IRDE ', ' Renault Kiger RXZ 1.0 MT ', ' MG ASTOR SHARP (O) 1.5 CV', ' Honda City VX MT PETROL M', ' Jaguar XF 2.2 DIESEL AUTO', ' Renault Kwid 1.0 RXT Opt ', ' Hyundai NEW SANTRO 1.1 ER', ' Tata ALTROZ XM+ 1.2 RTN', ' Maruti Swift LXI MANUAL', ' KIA SELTOS HTK PLUS 1.5 D', ' Maruti Swift LXI MANUAL', ' Maruti Dzire LXI MANUAL', ' Honda WR-V 1.2 i-VTEC VX ', ' KIA SELTOS GTX + AT PETRO', ' Tata ALTROZ XE 1.2 MANUAL', ' MG HECTOR PLUS SHARP DCT', ' Nissan MAGNITE XL Turbo M', ' Renault Kiger RXT 1.0 AMT', ' Hyundai i10 MAGNA 1.2 KAP', ' Tata ALTROZ XZ 1.2 MANUAL', ' Hyundai i10 MAGNA 1.1 IRD', ' Maruti Alto 800 VXI MANUA', ' Maruti Alto LXI MANUAL', ' Hyundai i10 ERA 1.1 IRDE ', ' Maruti Baleno SIGMA 1.2 K', ' Jeep Compass 1.4 SPORT PE', ' KIA SELTOS HTK 1.5 PETR
# ...

# %%
len(Car)
# Out:
# 5084

# %% [markdown]
# # MODEL NAME

# %%
Model.extend(modelsss)
print(Model)
# Out:
# ['2019', '2020', '2020', '2019', '2020', '2014', '2020', '2013', '2021', '2022', '2014', '2013', '2021', '2020', '2021', '2021', '2019', '2019', '2018', '2017', '2019', '2021', '2020', '2022', '2021', '2011', '2022', '2014', '2014', '2010', '2009', '2020', '2019', '2020', '2020', '2020', '2021', '2021', '2014', '2019', '2019', '2020', '2014', '2021', '2018', '2013', '2015', '2017', '2012', '2016', '2021', '2020', '2021', '2017', '2020', '2013', '2015', '2014', '2019', '2020', '2020', '2020', '2021', '2015', '2019', '2013', '2018', '2014', '2021', '2021', '2020', '2016', '2015', '2019', '2011', '2019', '2021', '2021', '2013', '2016', '2018', '2013', '2021', '2019', '2019', '2020', '2020', '2021', '2021', '2013', '2010', '2014', '2021', '2018', '2021', '2019', '2019', '2017', '2021', '2015', '2018', '2018', '2019', '2020', '2020', '2018', '2017', '2018', '2021', '2021', '2020', '2011', '2019', '2020', '2018', '2020', '2018', '2018', '2019', '2016', '2019', '2022', '2010', '2021', '2016
# ...

# %%
len(Model)
# Out:
# 5084

# %% [markdown]
# # PRICE

# %%
Price.extend(Pric)
print(Price)
# Out:
# ['₹9,81,699', '₹18,95,199', '₹5,92,499', '₹5,33,399', '₹13,83,099', '₹20,33,499', '₹5,66,799', '₹2,71,699', '₹8,23,199', '₹17,67,999', '₹6,58,499', '₹15,49,999', '₹5,05,099', '₹4,71,599', ',20,176', '₹6,11,299', '₹13,07,499', ',56,999', '₹5,42,299', ',79,899', '₹16,59,099', '₹6,41,999', '₹18,90,299', '₹8,43,099', '₹8,30,299', '₹2,82,899', '₹8,61,699', '₹3,49,399', '₹2,70,299', '₹1,70,299', ',99,699', '₹6,00,999', '₹13,76,149', '₹11,89,899', '₹18,48,299', '₹6,08,399', '₹4,63,499', '₹11,83,499', '₹2,75,299', '20,12,799', '₹19,41,699', '₹4,06,399', '₹3,39,599', '₹7,07,999', '₹11,49,399', '₹11,26,499', '₹5,30,099', '₹7,32,399', '₹2,57,999', '₹5,38,599', '₹13,84,399', '₹4,52,199', '₹7,31,399', '₹7,88,599', '₹17,55,399', '₹3,98,999', '₹4,32,499', '₹3,42,699', '₹17,94,899', '₹13,14,099', '₹5,06,599', '₹14,65,299', '₹8,41,249', '₹6,08,199', '₹6,03,299', '₹5,23,299', '₹4,08,999', '₹5,49,799', '₹9,01,699', '₹4,73,299', '₹15,39,699', '₹4,94,199', '₹5,43,799', '₹5,40,599', '₹2,59,399', '₹7,88,69
# ...

# %%
len(Price)
# Out:
# 5084

# %% [markdown]
# # DRIVEN KILOMETERS

# %%
driven.extend(driv)
print(driven)
# Out:
# ['81,902 km', '8,241 km', '10,568 km', '27,659 km', '32,799 km', '37,531 km', '19,919 km', '38,139 km', '14,474 km', '2,091 km', '61,168 km', '28,909 km', '368 km', '3,812 km', '7,416 km', '5,078 km', '25,067 km', '24,967 km', '25,788 km', '17,511 km', '37,357 km', '7,472 km', '3,483 km', '5,306 km', '6,192 km', '72,229 km', '1,086 km', '41,439 km', '28,210 km', '48,001 km', '44,327 km', '13,525 km', '42,490 km', '32,873 km', '12,185 km', '6,470 km', '13,021 km', '6,724 km', '63,753 km', '23,327 km', '46,860 km', '6,669 km', '41,822 km', '15,844 km', '34,073 km', '71,180 km', '25,414 km', '58,689 km', '55,018 km', '48,381 km', '38,187 km', '10,572 km', '649 km', '38,072 km', '16,315 km', '25,068 km', '46,245 km', '59,277 km', '9,378 km', '19,359 km', '15,199 km', '33,981 km', '13,713 km', '36,483 km', '35,953 km', '60,368 km', '2,920 km', '83,263 km', '7,733 km', '2,863 km', '32,605 km', '20,452 km', '28,170 km', '21,043 km', '61,943 km', '13,291 km', '9,278 km', '9,236 km', '30,354 
# ...

# %%
len(driven)
# Out:
# 5084

# %% [markdown]
# # HISTORY

# %%
history.extend(hist)
print(history)
# Out:
# ['Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Accidental', 'Non-Ac
# ...

# %%
len(history)
# Out:
# 5084

# %% [markdown]
# # LAST SERVICE

# %%
ser.extend(serv)
print(ser)
# Out:
# ['81,902k', '8,241km', '10,568k', '27,659k', '32,799k', '37,531k', '19,919k', '38,139k', '14,474k', '2,091km', '61,168k', '28,909k', '368km (', '3,812km', '7,416km', '5,078km', '25,067k', '24,967k', '25,788k', '17,511k', '37,357k', '7,472km', '3,483km', '5,306km', '6,192km', '72,229k', '1,086km', '41,439k', '28,210k', '48,001k', '44,327k', '13,525k', '42,490k', '32,873k', '12,185k', '6,470km', '13,021k', '6,724km', '63,753k', '23,327k', '46,860k', '6,669km', '41,822k', '15,844k', '34,073k', '71,180k', '25,414k', '58,689k', '55,018k', '48,381k', '38,187k', '10,572k', '649km (', '38,072k', '16,315k', '25,068k', '46,245k', '59,277k', '9,378km', '19,359k', '15,199k', '33,981k', '13,713k', '36,483k', '35,953k', '60,368k', '2,920km', '83,263k', '7,733km', '2,863km', '32,605k', '20,452k', '28,170k', '21,043k', '61,943k', '13,291k', '9,278km', '9,236km', '30,354k', '48,225k', '96,751k', '59,194k', '15,795k', '45,067k', '12,452k', '7,632km', '12,418k', '35,187k', '14,458k', '65,005k', '55,163
# ...

# %%
len(ser)
# Out:
# 5084

# %% [markdown]
# # OWNER

# %%
owner.extend(own)
print(owner)
# Out:
# ['1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '2nd Owner', '1st Owner', '2nd Owner', '2nd Owner', '1st Owner', '2nd Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '2nd Owner', '1st Owner', '2nd Owner', '1st Owner', '1st Owner', '2nd Owner', '1st Owner', '2nd Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '2nd Owner', '3rd Owner', '1st Owner', '1st Owner', '2nd Owner', '1st Owner', '1st Owner', '1st Owner', '2nd Owner', '1st Owner', '2nd Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '2nd Owner', '1st Owner', '1st Owner', '1st Owner', '2nd Owner', '1st Owner', '1st Owner', '1st Owner', '1st Owner', '2nd Owner', '2nd Owner', '1st Owner', '1st Owner', '1st Owner', '2nd Owner', '1st Owne
# ...

# %%
len(owner)
# Out:
# 5084

# %% [markdown]
# # FUEL TYPE

# %%
fuel.extend(fue)
print(fuel)
# Out:
# ['Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Diesel', 'Diesel', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol
# ...

# %%
len(fuel)
# Out:
# 5084

# %% [markdown]
# # LOCATION

# %%
loc.extend(loci)
print(loc)
# Out:
# ['New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delhi', 'New Delh
# ...

# %%
len(loc)
# Out:
# 5084

# %%
data = pd.DataFrame({'CARS NAME':Car,'MODEL':Model,'PRICE':Price,'DRIVEN(IN KMS)':driven,'HISTORY':history,'LAST SERVICE':ser,'OWNER':owner,'FUEL TYPE':fuel,'LOCATION':loc})
data
# Out:
#                        CARS NAME MODEL       PRICE DRIVEN(IN KMS)  \
# 0      Hyundai Verna 1.6 SX VTVT  2019   ₹9,81,699      81,902 km
# 1      KIA SELTOS GTX + AT PETRO  2020  ₹18,95,199       8,241 km
# 2        Maruti Swift LXI MANUAL  2020   ₹5,92,499      10,568 km
# 3        Maruti Swift LXI MANUAL  2019   ₹5,33,399      27,659 km
# 4      KIA SELTOS HTX 1.5 PETROL  2020  ₹13,83,099      32,799 km
# ...                          ...   ...         ...            ...
# 5079   Maruti Vitara Brezza VDI   2018   ₹7,25,799      44,339 km
# 5080   Maruti IGNIS ZETA 1.2 K12  2017   ₹5,19,499      21,204 km
# 5081   Audi Q3 35 TDI Quattro AU  2015  ₹14,42,399      52,533 km
# 5082      Maruti Ritz VDI MANUAL  2014   ₹3,52,799      80,192 km
# 5083   Hyundai i20 Active 1.2 S   2015     ,98,979      73,080 km
#
#              HISTORY LAST SERVICE      OWNER FUEL TYPE   LOCATION
# 0     Non-Accidental      81,902k  1st Owner    Petrol  New Delhi
# ...

# %%
data.head()
# Out:
#                     CARS NAME MODEL       PRICE DRIVEN(IN KMS)  \
# 0   Hyundai Verna 1.6 SX VTVT  2019   ₹9,81,699      81,902 km
# 1   KIA SELTOS GTX + AT PETRO  2020  ₹18,95,199       8,241 km
# 2     Maruti Swift LXI MANUAL  2020   ₹5,92,499      10,568 km
# 3     Maruti Swift LXI MANUAL  2019   ₹5,33,399      27,659 km
# 4   KIA SELTOS HTX 1.5 PETROL  2020  ₹13,83,099      32,799 km
#
#           HISTORY LAST SERVICE      OWNER FUEL TYPE   LOCATION
# 0  Non-Accidental      81,902k  1st Owner    Petrol  New Delhi
# 1  Non-Accidental      8,241km  1st Owner    Petrol  New Delhi
# 2  Non-Accidental      10,568k  1st Owner    Petrol  New Delhi
# 3  Non-Accidental      27,659k  1st Owner    Petrol  New Delhi
# 4  Non-Accidental      32,799k  1st Owner    Petrol  New Delhi

# %%
data.to_excel("C:\\Users\\LENOVO\\Desktop\\DATa.xlsx")
